# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv('tile_edge.csv')
df
# Out:
#                         Product_Name                              Color  \
# 0                    TILE EDGE SATIN                     CLEAR ANODIZED
# 1                    TILE EDGE SATIN                              BLACK
# 2   TILE EDGE SCHIENE-SATIN AE80/300                  ANODIZED ALUMINUM
# 3                      TILE EDGE 8FT                       BRIGHT CLEAR
# 4      TILE EDGE SCHIENE SATIN AE125                  ANODIZED ALUMINUM
# 5         TILE EDGE SATIN AE 100/300                  ANODIZED ALUMINUM
# 6                   TILE ROUND SATIN                     CLEAR ANODIZED
# 7                    RONDEC RO100AC6  POLISHED CHROME ANODIZED ALUMINUM
# 8                     JOLLY A100A6RB            ANODIZED BLACK ALUMINUM
# 9                              JOLLY  POLISHED CHROME ANODIZED ALUMINUM
# 10                  TILE ROUND SATIN                              BLACK
# 11             TILE CONTRACTOR SATIN                              CLEAR
# ...

# %%
df[df.Product_Name == 'TILE EDGE 8FT'].value_counts()
# Out:
# Product_Name   Color         Size         Quantity
# TILE EDGE 8FT  BRIGHT CLEAR  1/4IN (8MM)  3           1
# dtype: int64
