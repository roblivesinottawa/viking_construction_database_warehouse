# %%
import pandas as pd 
import numpy as np
import csv

# %%
header = ['Product_Name', 'Weight',	'Colour', 'Brand', 'Quantity']
data = [
    ['PRE-BLENDED MORTAR', '30KG','n/a', 'n/a', 12],
    ['LTC MORTAR ADHESIVE', '50LBS / 22.7KG', 'n/a', 'n/a',	3],
    ['MORTAR MIX', '30KG / 66LBS', 'GREY',	'BOMIX', 3],
    ['CONCRETE MIX', '30KG / 66LBS', 'n/a',	'BOMIX', 4],
    ['SAND MIX', '30KG / 66LBS', 'n/a',	'BOMIX', 1.5],
    ['PRO SET SF UNIVERSAL', '50LBS / 22.7KG', 'GREY', 'SCHLUTER', 4],
    ['PRO FLEX ', '50LBS / 22.7KG',	'GREY', 'SCHLUTER',	2],
    ['DRYWALL COMPOUND', '11KG', 'n/a', 'SHEETROCK 90',	2],
    ['LIGHTWEIGHT LATEX MODIFIED THIN SET MORTAR', '11.3 / 4KG', 'n/a', 'n/a', 2],
    ['ULTRALITE MORTAR', '25LBS/11.3KG', 'n/a', 'MAPEI', 10],
    ['ULTRAFLEX LFT', '50LBS / 22.7KG',	'GRAY', 'MAPEI', 10.5],
    ['ULTRAPLAN 1 PLUS', '50LBS / 22.7KG', 'n/a', 'MAPEI', 9],
    ['SET', '50LBS / 22.7KG', 'GRAY', 'SCHLUTER', 8],
    ['ALL-SET', '50LBS / 22.7KG', 'GRAY', 'SCHLUTER', 49],
    ['KERAPOXY', '1GAL', 'FROST', 'MAPEI', 5],
    ['TYPE 1 TILE ADHESIVE', '1GAL', 'n/a', 'MAPEI', 6],
    ['ROBERTS 2057 VCT ADHESIVE', '1GAL', 'n/a', 'ROBERTS 2057', 1],
    ['FLEXCOLOR CQ', '1GAL', 'BLACK (10)',	'MAPEI', 2],
    ['FLEXCOLOR CQ', '1GAL', 'CHAMOIS',	'MAPEI',	1],
    ['FLEXCOLOR CQ', '1GAL', 'PEWTER (02)',	'MAPEI', 1],
    ['FLEXCOLOR CQ', '1GAL', 'AVALANCHE (38)', 'MAPEI',	1],
    ['FLEXCOLOR CQ', '1GAL', 'SILVER (27)', 'MAPEI', 1],
    ['FLEXCOLOR CQ', '1GAL', 'RAIN (101)',	'MAPEI', 2],
    ['FLEXCOLOR CQ', '1GAL', 'WHITE (00)',	'MAPEI', 1],
    ['FLEXCOLOR CQ', '1GAL', 'FROST (77)',	'MAPEI', 4],
    ['FLEXCOLOR CQ', '1GAL', 'WALNUT (106)', 'MAPEI', 1],
    ['FLEXCOLOR CQ', '0.5GAL', 'SILVER (27)', 'MAPEI', 1],
    ['TYPE 1 TILE ADHESIVE', '3.5GALS', 'n/a', 'MAPEI', 1],
    ['ULTRACOLOR PLUS FA', '10LBS', 'PEARL GRAY (19)', 'MAPEI', 2],
    ['ULTRACOLOR PLUS FA', '10LBS', 'COBBLESTONE (103)', 'MAPEI', 1],
    ['ULTRACOLOR PLUS FA', '10LBS', 'BLACK (10)', 'MAPEI', 1],
    ['ULTRACOLOR PLUS FA', '10LBS', 'TIMBERWOLF (104)', 'MAPEI', 2],
    ['ULTRACOLOR PLUS FA', '10LBS', 'AVALANCHE (38)', 'MAPEI', 1],
    ['ULTRACOLOR PLUS FA', '10LBS', 'MOCHA (42)', 'MAPEI', 1],
    ['ULTRACOLOR PLUS FA', '10LBS', 'CHARCOAL (47)', 'MAPEI', 1],
    ['ULTRACOLOR PLUS FA', '10LBS', 'IVORY (39)', 'MAPEI', 1],
    ['ULTRACOLOR PLUS FA', '10LBS', 'NAVAJO BROWN (35)', 'MAPEI', 1],
    ['ULTRACOLOR PLUS FA', '10LBS', 'PEWTER (02)', 'MAPEI', 1],
    ['ULTRACOLOR PLUS FA', '25LBS/11.3KG', 'PEWTER (02)', 'MAPEI', 1],
    ['ULTRACOLOR PLUS FA', '25LBS/11.3KG', 'CHARCOAL (47)', 'MAPEI', 1],
    ['ULTRACOLOR PLUS FA', '25LBS/11.3KG', 'SAHARA BEIGE (11)', 'MAPEI', 2],
    ['KERACOLOR U', '10LBS', 'SILVER (27)', 'MAPEI', 1]
]

with open('cement_inventory.csv', 'w', encoding='UTF8', newline='') as file:
    writer = csv.writer(file)

    writer.writerow(header)
    writer.writerows(data)

# %%
df = pd.read_csv('cement_inventory.csv')
df.head()
# Out:
#           Product_Name          Weight Colour  Brand  Quantity
# 0   PRE-BLENDED MORTAR            30KG    NaN    NaN      12.0
# 1  LTC MORTAR ADHESIVE  50LBS / 22.7KG    NaN    NaN       3.0
# 2           MORTAR MIX    30KG / 66LBS   GREY  BOMIX       3.0
# 3         CONCRETE MIX    30KG / 66LBS    NaN  BOMIX       4.0
# 4             SAND MIX    30KG / 66LBS    NaN  BOMIX       1.5

# %%
df
# Out:
#                                   Product_Name          Weight  \
# 0                           PRE-BLENDED MORTAR            30KG
# 1                          LTC MORTAR ADHESIVE  50LBS / 22.7KG
# 2                                   MORTAR MIX    30KG / 66LBS
# 3                                 CONCRETE MIX    30KG / 66LBS
# 4                                     SAND MIX    30KG / 66LBS
# 5                         PRO SET SF UNIVERSAL  50LBS / 22.7KG
# 6                                    PRO FLEX   50LBS / 22.7KG
# 7                             DRYWALL COMPOUND            11KG
# 8   LIGHTWEIGHT LATEX MODIFIED THIN SET MORTAR      11.3 / 4KG
# 9                             ULTRALITE MORTAR    25LBS/11.3KG
# 10                               ULTRAFLEX LFT  50LBS / 22.7KG
# 11                            ULTRAPLAN 1 PLUS  50LBS / 22.7KG
# 12                                         SET  50LBS / 22.7KG
# 13                                     ALL-SET  50LBS / 22.7KG
# 14                                    KERAPOXY            1GAL
# 15                        TYPE 1 TILE ADHESIVE            1GAL
# 16                   ROBERTS 2057 VCT ADHESIVE            1GAL
# 17                                FLEXCOLOR CQ            1GAL
# 18                                FLEXCOLOR CQ            1GAL
# 19                                FLEXCOLOR CQ            1GAL
# 20                                FLEXCOLOR CQ            1GAL
# 21                                FLEXCOLOR CQ            1GAL
# 22                                FLEXCOLOR CQ            1GAL
# 23                                FLEXCOLOR CQ            1GAL
# 24                                FLEXCOLOR CQ            1GAL
# 25                                FLEXCOLOR CQ            1GAL
# 26                                FLEXCOLOR CQ          0.5GAL
# 27                        TYPE 1 TILE ADHESIVE         3.5GALS
# 28                          ULTRACOLOR PLUS FA           10LBS
# 29                          ULTRACOLOR PLUS FA           10LBS
# 30                          ULTRACOLOR PLUS FA           10LBS
# 31                          ULTRACOLOR PLUS FA           10LBS
# 32                          ULTRACOLOR PLUS FA           10LBS
# 33                          ULTRACOLOR PLUS FA           10LBS
# 34                          ULTRACOLOR PLUS FA           10LBS
# 35                          ULTRACOLOR PLUS FA           10LBS
# 36                          ULTRACOLOR PLUS FA           10LBS
# 37                          ULTRACOLOR PLUS FA           10LBS
# 38                          ULTRACOLOR PLUS FA    25LBS/11.3KG
# 39                          ULTRACOLOR PLUS FA    25LBS/11.3KG
# 40                          ULTRACOLOR PLUS FA    25LBS/11.3KG
# 41                                 KERACOLOR U           10LBS
#
#                Colour         Brand  Quantity
# 0                 NaN           NaN      12.0
# 1                 NaN           NaN       3.0
# 2                GREY         BOMIX       3.0
# 3                 NaN         BOMIX       4.0
# 4                 NaN         BOMIX       1.5
# 5                GREY      SCHLUTER       4.0
# 6                GREY      SCHLUTER       2.0
# 7                 NaN  SHEETROCK 90       2.0
# 8                 NaN           NaN       2.0
# 9                 NaN         MAPEI       4.5
# 10               GRAY         MAPEI      10.5
# 11                NaN         MAPEI       9.0
# 12               GRAY      SCHLUTER       8.0
# 13               GRAY      SCHLUTER      49.0
# 14              FROST         MAPEI       5.0
# 15                NaN         MAPEI       6.0
# 16                NaN  ROBERTS 2057       1.0
# 17         BLACK (10)         MAPEI       2.0
# 18            CHAMOIS         MAPEI       1.0
# 19        PEWTER (02)         MAPEI       1.0
# 20     AVALANCHE (38)         MAPEI       1.0
# 21        SILVER (27)         MAPEI       1.0
# 22         RAIN (101)         MAPEI       2.0
# 23         WHITE (00)         MAPEI       1.0
# 24         FROST (77)         MAPEI       4.0
# 25       WALNUT (106)         MAPEI       1.0
# 26        SILVER (27)         MAPEI       1.0
# 27                NaN         MAPEI       1.0
# 28    PEARL GRAY (19)         MAPEI       2.0
# 29  COBBLESTONE (103)         MAPEI       1.0
# 30         BLACK (10)         MAPEI       1.0
# 31   TIMBERWOLF (104)         MAPEI       2.0
# 32     AVALANCHE (38)         MAPEI       1.0
# 33         MOCHA (42)         MAPEI       1.0
# 34      CHARCOAL (47)         MAPEI       1.0
# 35         IVORY (39)         MAPEI       1.0
# 36  NAVAJO BROWN (35)         MAPEI       1.0
# 37        PEWTER (02)         MAPEI       1.0
# 38        PEWTER (02)         MAPEI       1.0
# 39      CHARCOAL (47)         MAPEI       1.0
# 40  SAHARA BEIGE (11)         MAPEI       2.0
# 41        SILVER (27)         MAPEI       1.0

# %%
df.count()
# Out:
# Product_Name    42
# Weight          42
# Colour          31
# Brand           39
# Quantity        42
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_Name  42 non-null     object
#  1   Weight        42 non-null     object
#  2   Colour        31 non-null     object
#  3   Brand         39 non-null     object
#  4   Quantity      42 non-null     float64
# dtypes: float64(1), object(4)
# memory usage: 1.8+ KB

# %%
df[df.Product_Name == 'ULTRACOLOR PLUS FA']
# Out:
#           Product_Name        Weight             Colour  Brand  Quantity
# 28  ULTRACOLOR PLUS FA         10LBS    PEARL GRAY (19)  MAPEI       2.0
# 29  ULTRACOLOR PLUS FA         10LBS  COBBLESTONE (103)  MAPEI       1.0
# 30  ULTRACOLOR PLUS FA         10LBS         BLACK (10)  MAPEI       1.0
# 31  ULTRACOLOR PLUS FA         10LBS   TIMBERWOLF (104)  MAPEI       2.0
# 32  ULTRACOLOR PLUS FA         10LBS     AVALANCHE (38)  MAPEI       1.0
# 33  ULTRACOLOR PLUS FA         10LBS         MOCHA (42)  MAPEI       1.0
# 34  ULTRACOLOR PLUS FA         10LBS      CHARCOAL (47)  MAPEI       1.0
# 35  ULTRACOLOR PLUS FA         10LBS         IVORY (39)  MAPEI       1.0
# 36  ULTRACOLOR PLUS FA         10LBS  NAVAJO BROWN (35)  MAPEI       1.0
# 37  ULTRACOLOR PLUS FA         10LBS        PEWTER (02)  MAPEI       1.0
# 38  ULTRACOLOR PLUS FA  25LBS/11.3KG        PEWTER (02)  MAPEI       1.0
# 39  ULTRACOLOR PLUS FA  25LBS/11.3KG      CHARCOAL (47)  MAPEI       1.0
# 40  ULTRACOLOR PLUS FA  25LBS/11.3KG  SAHARA BEIGE (11)  MAPEI       2.0

# %%
df.to_excel('cement_inventory.xlsx', index=None, header=True)

# %%
df.head(10)
# Out:
#                                  Product_Name          Weight Colour  \
# 0                          PRE-BLENDED MORTAR            30KG    NaN
# 1                         LTC MORTAR ADHESIVE  50LBS / 22.7KG    NaN
# 2                                  MORTAR MIX    30KG / 66LBS   GREY
# 3                                CONCRETE MIX    30KG / 66LBS    NaN
# 4                                    SAND MIX    30KG / 66LBS    NaN
# 5                        PRO SET SF UNIVERSAL  50LBS / 22.7KG   GREY
# 6                                   PRO FLEX   50LBS / 22.7KG   GREY
# 7                            DRYWALL COMPOUND            11KG    NaN
# 8  LIGHTWEIGHT LATEX MODIFIED THIN SET MORTAR      11.3 / 4KG    NaN
# 9                            ULTRALITE MORTAR    25LBS/11.3KG    NaN
#
#           Brand  Quantity
# 0           NaN      12.0
# 1           NaN       3.0
# 2         BOMIX       3.0
# 3         BOMIX       4.0
# 4         BOMIX       1.5
# 5      SCHLUTER       4.0
# 6      SCHLUTER       2.0
# 7  SHEETROCK 90       2.0
# 8           NaN       2.0
# 9         MAPEI       4.5

# %%
import seaborn as sns
import matplotlib as plt

# %%
sns.set_style('darkgrid')

# %%
sns.catplot(data=df, kind='bar', x='Quantity', y='Product_Name')
